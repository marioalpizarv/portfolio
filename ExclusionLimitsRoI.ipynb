# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import math

# %%
curve_1 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_O1_1_cm2_wimpROI.txt", sep=' ')
x1 = curve_1['mass'].to_numpy()
y1 = curve_1['cross_section'].to_numpy()

curve_2 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_O1_1_cm2_plrROI.txt", sep=' ')
x2 = curve_2['mass'].to_numpy()
y2 = curve_2['cross_section'].to_numpy()


curve_3 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_O3_1_cm2_wimpROI.txt", sep=' ')
x3 = curve_3['mass'].to_numpy()
y3 = curve_3['cross_section'].to_numpy()

curve_4 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_O3_1_cm2_plrROI.txt", sep=' ')
x4 = curve_4['mass'].to_numpy()
y4 = curve_4['cross_section'].to_numpy()

curve_5 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_O5_1_cm2_wimpROI.txt", sep=' ')
x5 = curve_5['mass'].to_numpy()
y5 = curve_5['cross_section'].to_numpy()

curve_6 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_O5_1_cm2_plrROI.txt", sep=' ')
x6 = curve_6['mass'].to_numpy()
y6 = curve_6['cross_section'].to_numpy()


curve_7 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_O8_1_cm2_wimpROI.txt", sep=' ')
x7 = curve_7['mass'].to_numpy()
y7 = curve_7['cross_section'].to_numpy()

curve_8 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_O8_1_cm2_plrROI.txt", sep=' ')
x8 = curve_8['mass'].to_numpy()
y8 = curve_8['cross_section'].to_numpy()

curve_9 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_O11_1_cm2_wimpROI.txt", sep=' ')
x9 = curve_9['mass'].to_numpy()
y9 = curve_9['cross_section'].to_numpy()

curve_10 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_O11_1_cm2_plrROI.txt", sep=' ')
x10 = curve_10['mass'].to_numpy()
y10 = curve_10['cross_section'].to_numpy()

# %%
plt.plot(x1, y1, color = 'tab:cyan', linestyle='-', label = "Operator 1")
plt.plot(x2, y2, color = 'tab:cyan', linestyle='--')
plt.plot(x3, y3, color = 'tab:olive', label = "Operator 3")
plt.plot(x4, y4, color = 'tab:olive', linestyle='--')
plt.plot(x5, y5, color = 'tab:green', label = "Operator 5")
plt.plot(x6, y6, color = 'tab:green', linestyle='--')
plt.plot(x7, y7, color = 'tab:red', label = "Operator 8")
plt.plot(x8, y8, color = 'tab:red', linestyle='--')
plt.plot(x9, y9, color = 'tab:purple', label = "Operator 11")
plt.plot(x10, y10, color = 'tab:purple', linestyle='--')
plt.plot([0], [0], color = 'black', linestyle='-', label = "2nd Paper RoI")
plt.plot([0], [0], color = 'black', linestyle='--', label = "PLR RoI")

plt.xlabel('WIMP Mass (GeV)')
plt.ylabel('WIMP-Nucleon Cross Section (cm$^{2}$)')
plt.title('Cross Section for NREFT Operators using SHM')
plt.xscale("log")
plt.yscale("log")
plt.ylim(1e-47, 1e-20)

plt.legend(loc='upper right', ncol=2)
plt.savefig('/home/malpizar/Documents/maxpatch_nreft/prueba/RoI_wimp_plr_operators_cm2_shm_1.jpg') 
plt.show()

# %%
curve_11 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_electricDipole_1_coupling_wimpROI.txt", sep=' ')
x11 = curve_11['mass'].to_numpy()
y11 = curve_11['coupling'].to_numpy()

curve_12 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_electricDipole_1_coupling_plrROI_plrAcc.txt", sep=' ')
x12 = curve_12['mass'].to_numpy()
y12 = curve_12['coupling'].to_numpy()

curve_13 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_anapole_1_coupling_wimpROI.txt", sep=' ')
x13 = curve_13['mass'].to_numpy()
y13 = curve_13['coupling'].to_numpy()

curve_14 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_anapole_1_coupling_plrROI_plrAcc.txt", sep=' ')
x14 = curve_14['mass'].to_numpy()
y14 = curve_14['coupling'].to_numpy()

curve_15 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_magneticDipole_1_coupling_wimpROI.txt", sep=' ')
x15 = curve_15['mass'].to_numpy()
y15 = curve_15['coupling'].to_numpy()

curve_16 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_magneticDipole_1_coupling_plrROI_plrAcc.txt", sep=' ')
x16 = curve_16['mass'].to_numpy()
y16 = curve_16['coupling'].to_numpy()

curve_17 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_milicharge_1_coupling_wimpROI.txt", sep=' ')
x17 = curve_17['mass'].to_numpy()
y17 = curve_17['coupling'].to_numpy()

curve_18 = pd.read_csv("/home/malpizar/Documents/maxpatch_nreft/prueba/lim_shm_milicharge_1_coupling_plrROI_plrAcc.txt", sep=' ')
x18 = curve_18['mass'].to_numpy()
y18 = curve_18['coupling'].to_numpy()

# %%
plt.plot(x11, y11, color = 'tab:blue', linestyle='-', label = "electric dipole moment")
plt.plot(x12, y12, color = 'tab:blue', linestyle='--')
plt.plot(x13, y13, color = 'tab:orange', linestyle='-', label = "anapole moment")
plt.plot(x14, y14, color = 'tab:orange', linestyle='--')
plt.plot(x15, y15, color = 'tab:green', linestyle='-', label = "magnetic dipole moment")
plt.plot(x16, y16, color = 'tab:green', linestyle='--')
plt.plot(x17, y17, color = 'tab:red', linestyle='-', label = "milicharge")
plt.plot(x18, y18, color = 'tab:red', linestyle='--')
plt.plot([0], [0], color = 'black', linestyle='-', label = "2nd Paper RoI")
plt.plot([0], [0], color = 'black', linestyle='--', label = "PLR RoI and Acc")

plt.xlabel('WIMP Mass (GeV)')
plt.ylabel('Coupling Strength')
plt.title('NREFT Interactions using SHM')
plt.xscale("log")
plt.yscale("log")

plt.legend(loc='upper right', ncol=2)
plt.savefig('/home/malpizar/Documents/maxpatch_nreft/prueba/RoI_Acc_wimp_plr_interactions_coupling_shm_1.jpg') 
plt.show()
